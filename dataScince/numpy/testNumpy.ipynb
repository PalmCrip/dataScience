# %%
#创建一个3*2的数组
import numpy as np
arr=np.array([[1,2],[3,4],[5,6]])
print("形状shape",arr.shape)
print("纬度ndim：",arr.ndim)
print("总元素",arr.size)
print("元素类型dtype:",arr.dtype)
print("转置T:",arr)
# Out:
# 形状shape (3, 2)
# 纬度ndim： 2
# 总元素 6
# 元素类型dtype: int64
# 转置T: [[1 2]
#  [3 4]
#  [5 6]]

# %%
#数组内存计算
arr = np.array([[0, 1], [2, 3]], dtype=np.int32)
print("内存",arr.itemsize)
print("内存",arr.nbytes)
# Out:
# 内存 4
# 内存 16

# %%
### np.lineSpace：等间隔数组
import numpy as np
### zeros_like(): 返回与给定数据具有相同形状和类型的0新书组
### ones_like()：返回与给定数组具有相同形状和类型的1新数组。
###  empty_like()：返回与给定数组具有相同形状和类型的未初始化的新数组。

arr2 = np.ones_like(arr, dtype=int)
arr4 = np.empty_like(arr2)
arr2 = np.full_like(arr2,5)

# %%
#快速初始化固定形状的数组，常用于占位或初始化权重矩阵

import numpy as np

ones_arr = np.ones((3, 2), dtype=int)
print(ones_arr)
# Out:
# [[1 1]
#  [1 1]
#  [1 1]]

# %%
arr = np.linspace(0,1,5) ## 0,1之间生成等间隔值
### 对数间隔
np.logspace(0,2,3) ### 返回指定数范围，元素个数，底数的等比数列

# %%
#### 随机数组
### np.random.rand
#### 返回给定形状的数组，用 [0, 1) 上均匀分布的随机样本填充。
np.random.rand(3,4)
#### 正态分布
np.random.randn(3,4)
